# %% [markdown]
# # Weather API Data Analysis – 10 Day Forecast

# %% [markdown]
# ## Objective
# To analyze 10-day weather forecast data for a selected city using a public Weather API, extract daily minimum and maximum temperatures, and identify the highest and lowest temperatures across the forecast period to understand short-term temperature patterns.

# %% [markdown]
# ## 1. Import Required Libraries

# %%
import requests
import json
from datetime import datetime

import os
from dotenv import load_dotenv

load_dotenv()
API_KEY = os.getenv("OPENWEATHER_API_KEY")

# %% [markdown]
# ## Data Source
# Weather data is fetched using the OpenWeather API, which returns forecast data in JSON format.

# %% [markdown]
# ## 2. API URL & Request

# %%
url="https://api.openweathermap.org/data/2.5/forecast?q=Hyderabad,IN&units=metric&appid={API_KEY}"
resp=requests.get(url)

# %% [markdown]
# ## 3. Response Validation

# %%
if resp.status_code==200:
    print("Response object loaded successfully")
    data=resp.content
else:
    print("Response object failed to load")
# Out:
# Response object loaded successfully

# %%
type(data)
# Out:
# bytes

# %% [markdown]
# ---
# ## 4. JSON Parsing (Bytes → Python Dictionary)

# %%
data=json.loads(data)

# %%
type(data)
# Out:
# dict

# %%
data
# Out:
# {'cod': '200',
#  'message': 0,
#  'cnt': 40,
#  'list': [{'dt': 1767376800,
#    'main': {'temp': 23.23,
#     'feels_like': 23.38,
#     'temp_min': 22.49,
#     'temp_max': 23.23,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 951,
#     'humidity': 68,
#     'temp_kf': 0.74},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 40},
#    'wind': {'speed': 3.36, 'deg': 86, 'gust': 6.59},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-01-02 18:00:00'},
#   {'dt': 1767387600,
#    'main': {'temp': 22.46,
#     'feels_like': 22.48,
#     'temp_min': 20.92,
#     'temp_max': 22.46,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 950,
#     'humidity': 66,
#     'temp_kf': 1.54},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 41},
#    'wind': {'speed': 3.7, 'deg': 97, 'gust': 7.2},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-01-02 21:00:00'},
#   {'dt': 1767398400,
#    'main': {'temp': 20.76,
#     'feels_like': 20.95,
#     'temp_min': 19.53,
#     'temp_max': 20.76,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 950,
#     'humidity': 79,
#     'temp_kf': 1.23},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 52},
#    'wind': {'speed': 3.55, 'deg': 105, 'gust': 7.13},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-01-03 00:00:00'},
#   {'dt': 1767409200,
#    'main': {'temp': 20.61,
#     'feels_like': 20.76,
#     'temp_min': 20.61,
#     'temp_max': 20.61,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 953,
#     'humidity': 78,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 61},
#    'wind': {'speed': 4.15, 'deg': 124, 'gust': 6.5},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-01-03 03:00:00'},
#   {'dt': 1767420000,
#    'main': {'temp': 25.98,
#     'feels_like': 25.98,
#     'temp_min': 25.98,
#     'temp_max': 25.98,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 953,
#     'humidity': 49,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 33},
#    'wind': {'speed': 4.74, 'deg': 124, 'gust': 4.54},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-01-03 06:00:00'},
#   {'dt': 1767430800,
#    'main': {'temp': 28.32,
#     'feels_like': 27.74,
#     'temp_min': 28.32,
#     'temp_max': 28.32,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 949,
#     'humidity': 37,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 14},
#    'wind': {'speed': 2.95, 'deg': 100, 'gust': 2.33},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-01-03 09:00:00'},
#   {'dt': 1767441600,
#    'main': {'temp': 26.12,
#     'feels_like': 26.12,
#     'temp_min': 26.12,
#     'temp_max': 26.12,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 949,
#     'humidity': 42,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 36},
#    'wind': {'speed': 4.34, 'deg': 119, 'gust': 5.66},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-01-03 12:00:00'},
#   {'dt': 1767452400,
#    'main': {'temp': 24.4,
#     'feels_like': 24.12,
#     'temp_min': 24.4,
#     'temp_max': 24.4,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 952,
#     'humidity': 47,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 79},
#    'wind': {'speed': 4.12, 'deg': 118, 'gust': 7.16},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-01-03 15:00:00'},
#   {'dt': 1767463200,
#    'main': {'temp': 21.92,
#     'feels_like': 21.68,
#     'temp_min': 21.92,
#     'temp_max': 21.92,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 952,
#     'humidity': 58,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 65},
#    'wind': {'speed': 4.29, 'deg': 125, 'gust': 9.17},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-01-03 18:00:00'},
#   {'dt': 1767474000,
#    'main': {'temp': 20.5,
#     'feels_like': 20.43,
#     'temp_min': 20.5,
#     'temp_max': 20.5,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 951,
#     'humidity': 70,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 51},
#    'wind': {'speed': 2.65, 'deg': 156, 'gust': 5.37},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-01-03 21:00:00'},
#   {'dt': 1767484800,
#    'main': {'temp': 18.76,
#     'feels_like': 18.78,
#     'temp_min': 18.76,
#     'temp_max': 18.76,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 951,
#     'humidity': 80,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 50},
#    'wind': {'speed': 2.83, 'deg': 120, 'gust': 4.42},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-01-04 00:00:00'},
#   {'dt': 1767495600,
#    'main': {'temp': 20.13,
#     'feels_like': 20.16,
#     'temp_min': 20.13,
#     'temp_max': 20.13,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 954,
#     'humidity': 75,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 36},
#    'wind': {'speed': 3.91, 'deg': 107, 'gust': 5.62},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-01-04 03:00:00'},
#   {'dt': 1767506400,
#    'main': {'temp': 26.11,
#     'feels_like': 26.11,
#     'temp_min': 26.11,
#     'temp_max': 26.11,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 953,
#     'humidity': 46,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 18},
#    'wind': {'speed': 4.39, 'deg': 99, 'gust': 4.31},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-01-04 06:00:00'},
#   {'dt': 1767517200,
#    'main': {'temp': 28.05,
#     'feels_like': 27.58,
#     'temp_min': 28.05,
#     'temp_max': 28.05,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 950,
#     'humidity': 38,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 32},
#    'wind': {'speed': 3.63, 'deg': 76, 'gust': 3.23},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-01-04 09:00:00'},
#   {'dt': 1767528000,
#    'main': {'temp': 26.22,
#     'feels_like': 26.22,
#     'temp_min': 26.22,
#     'temp_max': 26.22,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 950,
#     'humidity': 42,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 24},
#    'wind': {'speed': 3.66, 'deg': 101, 'gust': 4.77},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-01-04 12:00:00'},
#   {'dt': 1767538800,
#    'main': {'temp': 24.43,
#     'feels_like': 24.13,
#     'temp_min': 24.43,
#     'temp_max': 24.43,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 953,
#     'humidity': 46,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 84},
#    'wind': {'speed': 3.65, 'deg': 105, 'gust': 7.03},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-01-04 15:00:00'},
#   {'dt': 1767549600,
#    'main': {'temp': 21.67,
#     'feels_like': 21.35,
#     'temp_min': 21.67,
#     'temp_max': 21.67,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 952,
#     'humidity': 56,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 72},
#    'wind': {'speed': 3.07, 'deg': 79, 'gust': 5.42},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-01-04 18:00:00'},
#   {'dt': 1767560400,
#    'main': {'temp': 19.8,
#     'feels_like': 19.38,
#     'temp_min': 19.8,
#     'temp_max': 19.8,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 951,
#     'humidity': 59,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 2.28, 'deg': 81, 'gust': 3.03},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-01-04 21:00:00'},
#   {'dt': 1767571200,
#    'main': {'temp': 17.94,
#     'feels_like': 17.46,
#     'temp_min': 17.94,
#     'temp_max': 17.94,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 952,
#     'humidity': 64,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 2.71, 'deg': 77, 'gust': 3.6},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-01-05 00:00:00'},
#   {'dt': 1767582000,
#    'main': {'temp': 20.55,
#     'feels_like': 20.15,
#     'temp_min': 20.55,
#     'temp_max': 20.55,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 954,
#     'humidity': 57,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 3.24, 'deg': 89, 'gust': 5.04},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-01-05 03:00:00'},
#   {'dt': 1767592800,
#    'main': {'temp': 26.18,
#     'feels_like': 26.18,
#     'temp_min': 26.18,
#     'temp_max': 26.18,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 954,
#     'humidity': 33,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 4.52, 'deg': 67, 'gust': 5.36},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-01-05 06:00:00'},
#   {'dt': 1767603600,
#    'main': {'temp': 28.12,
#     'feels_like': 26.91,
#     'temp_min': 28.12,
#     'temp_max': 28.12,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 950,
#     'humidity': 23,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 4.32, 'deg': 66, 'gust': 4.94},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-01-05 09:00:00'},
#   {'dt': 1767614400,
#    'main': {'temp': 25.4,
#     'feels_like': 24.78,
#     'temp_min': 25.4,
#     'temp_max': 25.4,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 951,
#     'humidity': 30,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 3.66, 'deg': 75, 'gust': 5.06},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-01-05 12:00:00'},
#   {'dt': 1767625200,
#    'main': {'temp': 21.19,
#     'feels_like': 20.38,
#     'temp_min': 21.19,
#     'temp_max': 21.19,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 953,
#     'humidity': 39,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 1},
#    'wind': {'speed': 3.33, 'deg': 59, 'gust': 5.24},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-01-05 15:00:00'},
#   {'dt': 1767636000,
#    'main': {'temp': 19.47,
#     'feels_like': 18.57,
#     'temp_min': 19.47,
#     'temp_max': 19.47,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 952,
#     'humidity': 42,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 1},
#    'wind': {'speed': 1.42, 'deg': 89, 'gust': 1.96},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-01-05 18:00:00'},
#   {'dt': 1767646800,
#    'main': {'temp': 18.16,
#     'feels_like': 17.18,
#     'temp_min': 18.16,
#     'temp_max': 18.16,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 951,
#     'humidity': 44,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 2.4, 'deg': 79, 'gust': 3.21},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-01-05 21:00:00'},
#   {'dt': 1767657600,
#    'main': {'temp': 16.6,
#     'feels_like': 15.6,
#     'temp_min': 16.6,
#     'temp_max': 16.6,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 952,
#     'humidity': 49,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 2.01, 'deg': 64, 'gust': 2.63},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-01-06 00:00:00'},
#   {'dt': 1767668400,
#    'main': {'temp': 19.81,
#     'feels_like': 18.86,
#     'temp_min': 19.81,
#     'temp_max': 19.81,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 954,
#     'humidity': 39,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 2.83, 'deg': 72, 'gust': 4.23},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-01-06 03:00:00'},
#   {'dt': 1767679200,
#    'main': {'temp': 25.35,
#     'feels_like': 24.65,
#     'temp_min': 25.35,
#     'temp_max': 25.35,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 953,
#     'humidity': 27,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 2},
#    'wind': {'speed': 3.81, 'deg': 64, 'gust': 4.55},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-01-06 06:00:00'},
#   {'dt': 1767690000,
#    'main': {'temp': 27.64,
#     'feels_like': 26.61,
#     'temp_min': 27.64,
#     'temp_max': 27.64,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 950,
#     'humidity': 24,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 3.96, 'deg': 83, 'gust': 4.26},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-01-06 09:00:00'},
#   {'dt': 1767700800,
#    'main': {'temp': 25.02,
#     'feels_like': 24.6,
#     'temp_min': 25.02,
#     'temp_max': 25.02,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 951,
#     'humidity': 39,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 1},
#    'wind': {'speed': 3.23, 'deg': 92, 'gust': 4.4},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-01-06 12:00:00'},
#   {'dt': 1767711600,
#    'main': {'temp': 21.39,
#     'feels_like': 20.92,
#     'temp_min': 21.39,
#     'temp_max': 21.39,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 953,
#     'humidity': 51,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 41},
#    'wind': {'speed': 3.18, 'deg': 117, 'gust': 5.08},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-01-06 15:00:00'},
#   {'dt': 1767722400,
#    'main': {'temp': 19.54,
#     'feels_like': 19.12,
#     'temp_min': 19.54,
#     'temp_max': 19.54,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 953,
#     'humidity': 60,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 70},
#    'wind': {'speed': 1.88, 'deg': 130, 'gust': 2.59},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-01-06 18:00:00'},
#   {'dt': 1767733200,
#    'main': {'temp': 17.78,
#     'feels_like': 17.39,
#     'temp_min': 17.78,
#     'temp_max': 17.78,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 952,
#     'humidity': 68,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 25},
#    'wind': {'speed': 2.29, 'deg': 91, 'gust': 2.86},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-01-06 21:00:00'},
#   {'dt': 1767744000,
#    'main': {'temp': 16.09,
#     'feels_like': 16.05,
#     'temp_min': 16.09,
#     'temp_max': 16.09,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 952,
#     'humidity': 88,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 52},
#    'wind': {'speed': 3.04, 'deg': 102, 'gust': 4.22},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-01-07 00:00:00'},
#   {'dt': 1767754800,
#    'main': {'temp': 18.48,
#     'feels_like': 18.55,
#     'temp_min': 18.48,
#     'temp_max': 18.48,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 954,
#     'humidity': 83,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.52, 'deg': 125, 'gust': 5.22},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-01-07 03:00:00'},
#   {'dt': 1767765600,
#    'main': {'temp': 24.59,
#     'feels_like': 24.31,
#     'temp_min': 24.59,
#     'temp_max': 24.59,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 954,
#     'humidity': 46,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 89},
#    'wind': {'speed': 3.65, 'deg': 108, 'gust': 4.33},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-01-07 06:00:00'},
#   {'dt': 1767776400,
#    'main': {'temp': 26.47,
#     'feels_like': 26.47,
#     'temp_min': 26.47,
#     'temp_max': 26.47,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 951,
#     'humidity': 34,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 88},
#    'wind': {'speed': 4.33, 'deg': 101, 'gust': 4.58},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-01-07 09:00:00'},
#   {'dt': 1767787200,
#    'main': {'temp': 23.81,
#     'feels_like': 23.34,
#     'temp_min': 23.81,
#     'temp_max': 23.81,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 951,
#     'humidity': 42,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 94},
#    'wind': {'speed': 3.75, 'deg': 111, 'gust': 5},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-01-07 12:00:00'},
#   {'dt': 1767798000,
#    'main': {'temp': 20.38,
#     'feels_like': 19.88,
#     'temp_min': 20.38,
#     'temp_max': 20.38,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 953,
#     'humidity': 54,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.33, 'deg': 120, 'gust': 5.06},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-01-07 15:00:00'}],
#  'city': {'id': 1269843,
#   'name': 'Hyderabad',
#   'coord': {'lat': 17.3753, 'lon': 78.4744},
#   'country': 'IN',
#   'population': 3597816,
#   'timezone': 19800,
#   'sunrise': 1767316585,
#   'sunset': 1767356589}}

# %% [markdown]
# ## 5. Data Structure Exploration

# %%
data.keys()
# Out:
# dict_keys(['cod', 'message', 'cnt', 'list', 'city'])

# %%
print(type(data['list']))
# Out:
# <class 'list'>

# %%
data['list']
# Out:
# [{'dt': 1767376800,
#   'main': {'temp': 23.23,
#    'feels_like': 23.38,
#    'temp_min': 22.49,
#    'temp_max': 23.23,
#    'pressure': 1015,
#    'sea_level': 1015,
#    'grnd_level': 951,
#    'humidity': 68,
#    'temp_kf': 0.74},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'clouds': {'all': 40},
#   'wind': {'speed': 3.36, 'deg': 86, 'gust': 6.59},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-01-02 18:00:00'},
#  {'dt': 1767387600,
#   'main': {'temp': 22.46,
#    'feels_like': 22.48,
#    'temp_min': 20.92,
#    'temp_max': 22.46,
#    'pressure': 1015,
#    'sea_level': 1015,
#    'grnd_level': 950,
#    'humidity': 66,
#    'temp_kf': 1.54},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'clouds': {'all': 41},
#   'wind': {'speed': 3.7, 'deg': 97, 'gust': 7.2},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-01-02 21:00:00'},
#  {'dt': 1767398400,
#   'main': {'temp': 20.76,
#    'feels_like': 20.95,
#    'temp_min': 19.53,
#    'temp_max': 20.76,
#    'pressure': 1014,
#    'sea_level': 1014,
#    'grnd_level': 950,
#    'humidity': 79,
#    'temp_kf': 1.23},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 52},
#   'wind': {'speed': 3.55, 'deg': 105, 'gust': 7.13},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-01-03 00:00:00'},
#  {'dt': 1767409200,
#   'main': {'temp': 20.61,
#    'feels_like': 20.76,
#    'temp_min': 20.61,
#    'temp_max': 20.61,
#    'pressure': 1017,
#    'sea_level': 1017,
#    'grnd_level': 953,
#    'humidity': 78,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 61},
#   'wind': {'speed': 4.15, 'deg': 124, 'gust': 6.5},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-01-03 03:00:00'},
#  {'dt': 1767420000,
#   'main': {'temp': 25.98,
#    'feels_like': 25.98,
#    'temp_min': 25.98,
#    'temp_max': 25.98,
#    'pressure': 1016,
#    'sea_level': 1016,
#    'grnd_level': 953,
#    'humidity': 49,
#    'temp_kf': 0},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'clouds': {'all': 33},
#   'wind': {'speed': 4.74, 'deg': 124, 'gust': 4.54},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-01-03 06:00:00'},
#  {'dt': 1767430800,
#   'main': {'temp': 28.32,
#    'feels_like': 27.74,
#    'temp_min': 28.32,
#    'temp_max': 28.32,
#    'pressure': 1012,
#    'sea_level': 1012,
#    'grnd_level': 949,
#    'humidity': 37,
#    'temp_kf': 0},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'clouds': {'all': 14},
#   'wind': {'speed': 2.95, 'deg': 100, 'gust': 2.33},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-01-03 09:00:00'},
#  {'dt': 1767441600,
#   'main': {'temp': 26.12,
#    'feels_like': 26.12,
#    'temp_min': 26.12,
#    'temp_max': 26.12,
#    'pressure': 1013,
#    'sea_level': 1013,
#    'grnd_level': 949,
#    'humidity': 42,
#    'temp_kf': 0},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'clouds': {'all': 36},
#   'wind': {'speed': 4.34, 'deg': 119, 'gust': 5.66},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-01-03 12:00:00'},
#  {'dt': 1767452400,
#   'main': {'temp': 24.4,
#    'feels_like': 24.12,
#    'temp_min': 24.4,
#    'temp_max': 24.4,
#    'pressure': 1015,
#    'sea_level': 1015,
#    'grnd_level': 952,
#    'humidity': 47,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 79},
#   'wind': {'speed': 4.12, 'deg': 118, 'gust': 7.16},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-01-03 15:00:00'},
#  {'dt': 1767463200,
#   'main': {'temp': 21.92,
#    'feels_like': 21.68,
#    'temp_min': 21.92,
#    'temp_max': 21.92,
#    'pressure': 1015,
#    'sea_level': 1015,
#    'grnd_level': 952,
#    'humidity': 58,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 65},
#   'wind': {'speed': 4.29, 'deg': 125, 'gust': 9.17},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-01-03 18:00:00'},
#  {'dt': 1767474000,
#   'main': {'temp': 20.5,
#    'feels_like': 20.43,
#    'temp_min': 20.5,
#    'temp_max': 20.5,
#    'pressure': 1014,
#    'sea_level': 1014,
#    'grnd_level': 951,
#    'humidity': 70,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 51},
#   'wind': {'speed': 2.65, 'deg': 156, 'gust': 5.37},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-01-03 21:00:00'},
#  {'dt': 1767484800,
#   'main': {'temp': 18.76,
#    'feels_like': 18.78,
#    'temp_min': 18.76,
#    'temp_max': 18.76,
#    'pressure': 1015,
#    'sea_level': 1015,
#    'grnd_level': 951,
#    'humidity': 80,
#    'temp_kf': 0},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'clouds': {'all': 50},
#   'wind': {'speed': 2.83, 'deg': 120, 'gust': 4.42},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-01-04 00:00:00'},
#  {'dt': 1767495600,
#   'main': {'temp': 20.13,
#    'feels_like': 20.16,
#    'temp_min': 20.13,
#    'temp_max': 20.13,
#    'pressure': 1018,
#    'sea_level': 1018,
#    'grnd_level': 954,
#    'humidity': 75,
#    'temp_kf': 0},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'clouds': {'all': 36},
#   'wind': {'speed': 3.91, 'deg': 107, 'gust': 5.62},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-01-04 03:00:00'},
#  {'dt': 1767506400,
#   'main': {'temp': 26.11,
#    'feels_like': 26.11,
#    'temp_min': 26.11,
#    'temp_max': 26.11,
#    'pressure': 1017,
#    'sea_level': 1017,
#    'grnd_level': 953,
#    'humidity': 46,
#    'temp_kf': 0},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'clouds': {'all': 18},
#   'wind': {'speed': 4.39, 'deg': 99, 'gust': 4.31},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-01-04 06:00:00'},
#  {'dt': 1767517200,
#   'main': {'temp': 28.05,
#    'feels_like': 27.58,
#    'temp_min': 28.05,
#    'temp_max': 28.05,
#    'pressure': 1013,
#    'sea_level': 1013,
#    'grnd_level': 950,
#    'humidity': 38,
#    'temp_kf': 0},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'clouds': {'all': 32},
#   'wind': {'speed': 3.63, 'deg': 76, 'gust': 3.23},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-01-04 09:00:00'},
#  {'dt': 1767528000,
#   'main': {'temp': 26.22,
#    'feels_like': 26.22,
#    'temp_min': 26.22,
#    'temp_max': 26.22,
#    'pressure': 1013,
#    'sea_level': 1013,
#    'grnd_level': 950,
#    'humidity': 42,
#    'temp_kf': 0},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'clouds': {'all': 24},
#   'wind': {'speed': 3.66, 'deg': 101, 'gust': 4.77},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-01-04 12:00:00'},
#  {'dt': 1767538800,
#   'main': {'temp': 24.43,
#    'feels_like': 24.13,
#    'temp_min': 24.43,
#    'temp_max': 24.43,
#    'pressure': 1016,
#    'sea_level': 1016,
#    'grnd_level': 953,
#    'humidity': 46,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 84},
#   'wind': {'speed': 3.65, 'deg': 105, 'gust': 7.03},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-01-04 15:00:00'},
#  {'dt': 1767549600,
#   'main': {'temp': 21.67,
#    'feels_like': 21.35,
#    'temp_min': 21.67,
#    'temp_max': 21.67,
#    'pressure': 1016,
#    'sea_level': 1016,
#    'grnd_level': 952,
#    'humidity': 56,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 72},
#   'wind': {'speed': 3.07, 'deg': 79, 'gust': 5.42},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-01-04 18:00:00'},
#  {'dt': 1767560400,
#   'main': {'temp': 19.8,
#    'feels_like': 19.38,
#    'temp_min': 19.8,
#    'temp_max': 19.8,
#    'pressure': 1015,
#    'sea_level': 1015,
#    'grnd_level': 951,
#    'humidity': 59,
#    'temp_kf': 0},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'clouds': {'all': 0},
#   'wind': {'speed': 2.28, 'deg': 81, 'gust': 3.03},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-01-04 21:00:00'},
#  {'dt': 1767571200,
#   'main': {'temp': 17.94,
#    'feels_like': 17.46,
#    'temp_min': 17.94,
#    'temp_max': 17.94,
#    'pressure': 1016,
#    'sea_level': 1016,
#    'grnd_level': 952,
#    'humidity': 64,
#    'temp_kf': 0},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'clouds': {'all': 0},
#   'wind': {'speed': 2.71, 'deg': 77, 'gust': 3.6},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-01-05 00:00:00'},
#  {'dt': 1767582000,
#   'main': {'temp': 20.55,
#    'feels_like': 20.15,
#    'temp_min': 20.55,
#    'temp_max': 20.55,
#    'pressure': 1019,
#    'sea_level': 1019,
#    'grnd_level': 954,
#    'humidity': 57,
#    'temp_kf': 0},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'clouds': {'all': 0},
#   'wind': {'speed': 3.24, 'deg': 89, 'gust': 5.04},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-01-05 03:00:00'},
#  {'dt': 1767592800,
#   'main': {'temp': 26.18,
#    'feels_like': 26.18,
#    'temp_min': 26.18,
#    'temp_max': 26.18,
#    'pressure': 1017,
#    'sea_level': 1017,
#    'grnd_level': 954,
#    'humidity': 33,
#    'temp_kf': 0},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'clouds': {'all': 0},
#   'wind': {'speed': 4.52, 'deg': 67, 'gust': 5.36},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-01-05 06:00:00'},
#  {'dt': 1767603600,
#   'main': {'temp': 28.12,
#    'feels_like': 26.91,
#    'temp_min': 28.12,
#    'temp_max': 28.12,
#    'pressure': 1014,
#    'sea_level': 1014,
#    'grnd_level': 950,
#    'humidity': 23,
#    'temp_kf': 0},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'clouds': {'all': 0},
#   'wind': {'speed': 4.32, 'deg': 66, 'gust': 4.94},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-01-05 09:00:00'},
#  {'dt': 1767614400,
#   'main': {'temp': 25.4,
#    'feels_like': 24.78,
#    'temp_min': 25.4,
#    'temp_max': 25.4,
#    'pressure': 1014,
#    'sea_level': 1014,
#    'grnd_level': 951,
#    'humidity': 30,
#    'temp_kf': 0},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'clouds': {'all': 0},
#   'wind': {'speed': 3.66, 'deg': 75, 'gust': 5.06},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-01-05 12:00:00'},
#  {'dt': 1767625200,
#   'main': {'temp': 21.19,
#    'feels_like': 20.38,
#    'temp_min': 21.19,
#    'temp_max': 21.19,
#    'pressure': 1017,
#    'sea_level': 1017,
#    'grnd_level': 953,
#    'humidity': 39,
#    'temp_kf': 0},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'clouds': {'all': 1},
#   'wind': {'speed': 3.33, 'deg': 59, 'gust': 5.24},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-01-05 15:00:00'},
#  {'dt': 1767636000,
#   'main': {'temp': 19.47,
#    'feels_like': 18.57,
#    'temp_min': 19.47,
#    'temp_max': 19.47,
#    'pressure': 1017,
#    'sea_level': 1017,
#    'grnd_level': 952,
#    'humidity': 42,
#    'temp_kf': 0},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'clouds': {'all': 1},
#   'wind': {'speed': 1.42, 'deg': 89, 'gust': 1.96},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-01-05 18:00:00'},
#  {'dt': 1767646800,
#   'main': {'temp': 18.16,
#    'feels_like': 17.18,
#    'temp_min': 18.16,
#    'temp_max': 18.16,
#    'pressure': 1016,
#    'sea_level': 1016,
#    'grnd_level': 951,
#    'humidity': 44,
#    'temp_kf': 0},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'clouds': {'all': 0},
#   'wind': {'speed': 2.4, 'deg': 79, 'gust': 3.21},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-01-05 21:00:00'},
#  {'dt': 1767657600,
#   'main': {'temp': 16.6,
#    'feels_like': 15.6,
#    'temp_min': 16.6,
#    'temp_max': 16.6,
#    'pressure': 1016,
#    'sea_level': 1016,
#    'grnd_level': 952,
#    'humidity': 49,
#    'temp_kf': 0},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'clouds': {'all': 0},
#   'wind': {'speed': 2.01, 'deg': 64, 'gust': 2.63},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-01-06 00:00:00'},
#  {'dt': 1767668400,
#   'main': {'temp': 19.81,
#    'feels_like': 18.86,
#    'temp_min': 19.81,
#    'temp_max': 19.81,
#    'pressure': 1018,
#    'sea_level': 1018,
#    'grnd_level': 954,
#    'humidity': 39,
#    'temp_kf': 0},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'clouds': {'all': 0},
#   'wind': {'speed': 2.83, 'deg': 72, 'gust': 4.23},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-01-06 03:00:00'},
#  {'dt': 1767679200,
#   'main': {'temp': 25.35,
#    'feels_like': 24.65,
#    'temp_min': 25.35,
#    'temp_max': 25.35,
#    'pressure': 1017,
#    'sea_level': 1017,
#    'grnd_level': 953,
#    'humidity': 27,
#    'temp_kf': 0},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'clouds': {'all': 2},
#   'wind': {'speed': 3.81, 'deg': 64, 'gust': 4.55},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-01-06 06:00:00'},
#  {'dt': 1767690000,
#   'main': {'temp': 27.64,
#    'feels_like': 26.61,
#    'temp_min': 27.64,
#    'temp_max': 27.64,
#    'pressure': 1013,
#    'sea_level': 1013,
#    'grnd_level': 950,
#    'humidity': 24,
#    'temp_kf': 0},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'clouds': {'all': 0},
#   'wind': {'speed': 3.96, 'deg': 83, 'gust': 4.26},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-01-06 09:00:00'},
#  {'dt': 1767700800,
#   'main': {'temp': 25.02,
#    'feels_like': 24.6,
#    'temp_min': 25.02,
#    'temp_max': 25.02,
#    'pressure': 1014,
#    'sea_level': 1014,
#    'grnd_level': 951,
#    'humidity': 39,
#    'temp_kf': 0},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'clouds': {'all': 1},
#   'wind': {'speed': 3.23, 'deg': 92, 'gust': 4.4},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-01-06 12:00:00'},
#  {'dt': 1767711600,
#   'main': {'temp': 21.39,
#    'feels_like': 20.92,
#    'temp_min': 21.39,
#    'temp_max': 21.39,
#    'pressure': 1017,
#    'sea_level': 1017,
#    'grnd_level': 953,
#    'humidity': 51,
#    'temp_kf': 0},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'clouds': {'all': 41},
#   'wind': {'speed': 3.18, 'deg': 117, 'gust': 5.08},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-01-06 15:00:00'},
#  {'dt': 1767722400,
#   'main': {'temp': 19.54,
#    'feels_like': 19.12,
#    'temp_min': 19.54,
#    'temp_max': 19.54,
#    'pressure': 1017,
#    'sea_level': 1017,
#    'grnd_level': 953,
#    'humidity': 60,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 70},
#   'wind': {'speed': 1.88, 'deg': 130, 'gust': 2.59},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-01-06 18:00:00'},
#  {'dt': 1767733200,
#   'main': {'temp': 17.78,
#    'feels_like': 17.39,
#    'temp_min': 17.78,
#    'temp_max': 17.78,
#    'pressure': 1016,
#    'sea_level': 1016,
#    'grnd_level': 952,
#    'humidity': 68,
#    'temp_kf': 0},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'clouds': {'all': 25},
#   'wind': {'speed': 2.29, 'deg': 91, 'gust': 2.86},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-01-06 21:00:00'},
#  {'dt': 1767744000,
#   'main': {'temp': 16.09,
#    'feels_like': 16.05,
#    'temp_min': 16.09,
#    'temp_max': 16.09,
#    'pressure': 1017,
#    'sea_level': 1017,
#    'grnd_level': 952,
#    'humidity': 88,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 52},
#   'wind': {'speed': 3.04, 'deg': 102, 'gust': 4.22},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-01-07 00:00:00'},
#  {'dt': 1767754800,
#   'main': {'temp': 18.48,
#    'feels_like': 18.55,
#    'temp_min': 18.48,
#    'temp_max': 18.48,
#    'pressure': 1019,
#    'sea_level': 1019,
#    'grnd_level': 954,
#    'humidity': 83,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 3.52, 'deg': 125, 'gust': 5.22},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-01-07 03:00:00'},
#  {'dt': 1767765600,
#   'main': {'temp': 24.59,
#    'feels_like': 24.31,
#    'temp_min': 24.59,
#    'temp_max': 24.59,
#    'pressure': 1018,
#    'sea_level': 1018,
#    'grnd_level': 954,
#    'humidity': 46,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 89},
#   'wind': {'speed': 3.65, 'deg': 108, 'gust': 4.33},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-01-07 06:00:00'},
#  {'dt': 1767776400,
#   'main': {'temp': 26.47,
#    'feels_like': 26.47,
#    'temp_min': 26.47,
#    'temp_max': 26.47,
#    'pressure': 1014,
#    'sea_level': 1014,
#    'grnd_level': 951,
#    'humidity': 34,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 88},
#   'wind': {'speed': 4.33, 'deg': 101, 'gust': 4.58},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-01-07 09:00:00'},
#  {'dt': 1767787200,
#   'main': {'temp': 23.81,
#    'feels_like': 23.34,
#    'temp_min': 23.81,
#    'temp_max': 23.81,
#    'pressure': 1015,
#    'sea_level': 1015,
#    'grnd_level': 951,
#    'humidity': 42,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 94},
#   'wind': {'speed': 3.75, 'deg': 111, 'gust': 5},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-01-07 12:00:00'},
#  {'dt': 1767798000,
#   'main': {'temp': 20.38,
#    'feels_like': 19.88,
#    'temp_min': 20.38,
#    'temp_max': 20.38,
#    'pressure': 1017,
#    'sea_level': 1017,
#    'grnd_level': 953,
#    'humidity': 54,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 3.33, 'deg': 120, 'gust': 5.06},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-01-07 15:00:00'}]

# %%
data.keys()
# Out:
# dict_keys(['cod', 'message', 'cnt', 'list', 'city'])

# %%
data['list'][0] # we have our analysis required 'dt' in list, and min and max temperatures in temp list.
# Out:
# {'dt': 1767376800,
#  'main': {'temp': 23.23,
#   'feels_like': 23.38,
#   'temp_min': 22.49,
#   'temp_max': 23.23,
#   'pressure': 1015,
#   'sea_level': 1015,
#   'grnd_level': 951,
#   'humidity': 68,
#   'temp_kf': 0.74},
#  'weather': [{'id': 802,
#    'main': 'Clouds',
#    'description': 'scattered clouds',
#    'icon': '03n'}],
#  'clouds': {'all': 40},
#  'wind': {'speed': 3.36, 'deg': 86, 'gust': 6.59},
#  'visibility': 10000,
#  'pop': 0,
#  'sys': {'pod': 'n'},
#  'dt_txt': '2026-01-02 18:00:00'}

# %%
data['list'][0].keys()
# Out:
# dict_keys(['dt', 'main', 'weather', 'clouds', 'wind', 'visibility', 'pop', 'sys', 'dt_txt'])

# %%
print(type(data['list'][0]['main']))
# Out:
# <class 'dict'>

# %%
print(data['list'][0]['main'].keys())
# Out:
# dict_keys(['temp', 'feels_like', 'temp_min', 'temp_max', 'pressure', 'sea_level', 'grnd_level', 'humidity', 'temp_kf'])

# %%
hyd_weather_list=data['list']
hyd_weather_list[0]['main']
# Out:
# {'temp': 23.23,
#  'feels_like': 23.38,
#  'temp_min': 22.49,
#  'temp_max': 23.23,
#  'pressure': 1015,
#  'sea_level': 1015,
#  'grnd_level': 951,
#  'humidity': 68,
#  'temp_kf': 0.74}

# %%
hyd_weather_list[0]['dt'] # use datetime
# Out:
# 1767376800

# %% [markdown]
# ## 6. Daily Temperature Extraction

# %%
from datetime import datetime, UTC
maxtemp=[]
mintemp=[] # to collect max and min temperatures from temp.

for each in hyd_weather_list:
    date_ts=each['dt'] #this gives unix timestamp
    date=datetime.fromtimestamp(date_ts, UTC).strftime('%d-%m-%y') #correct date conversion
    maxtemp=each['main']['temp_max']
    mintemp=each['main']['temp_min']

    print(f'Date:{date} | Min Temp: {mintemp} | Max Temp: {maxtemp}')
# Out:
# Date:02-01-26 | Min Temp: 22.49 | Max Temp: 23.23
# Date:02-01-26 | Min Temp: 20.92 | Max Temp: 22.46
# Date:03-01-26 | Min Temp: 19.53 | Max Temp: 20.76
# Date:03-01-26 | Min Temp: 20.61 | Max Temp: 20.61
# Date:03-01-26 | Min Temp: 25.98 | Max Temp: 25.98
# Date:03-01-26 | Min Temp: 28.32 | Max Temp: 28.32
# Date:03-01-26 | Min Temp: 26.12 | Max Temp: 26.12
# Date:03-01-26 | Min Temp: 24.4 | Max Temp: 24.4
# Date:03-01-26 | Min Temp: 21.92 | Max Temp: 21.92
# Date:03-01-26 | Min Temp: 20.5 | Max Temp: 20.5
# Date:04-01-26 | Min Temp: 18.76 | Max Temp: 18.76
# Date:04-01-26 | Min Temp: 20.13 | Max Temp: 20.13
# Date:04-01-26 | Min Temp: 26.11 | Max Temp: 26.11
# Date:04-01-26 | Min Temp: 28.05 | Max Temp: 28.05
# Date:04-01-26 | Min Temp: 26.22 | Max Temp: 26.22
# Date:04-01-26 | Min Temp: 24.43 | Max Temp: 24.43
# Date:04-01-26 | Min Temp: 21.67 | Max Temp: 21.67
# Date:04-01-26 | Min Temp: 19.8 | Max Temp: 19.8
# Date:05-01-26 | Min Temp: 17.94 | Max Temp: 17.94
# Date:05-01-26 | Min Temp: 20.55 | Max Temp: 20.55
# Date:05-01-26 | Min Temp: 26.18 | Max Temp: 26.18
# Date:05-01-26 | Min Temp: 28.12 | Max Temp: 28.12
# Date:05-01-26 | Min Temp: 25.4 | Max Temp: 25.4
# Date:05-01-26 | Min Temp: 21.19 | Max Temp: 21.19
# Date:05-01-26 | Min Temp: 19.47 | Max Temp: 19.47
# Date:05-01-26 | Min Temp: 18.16 | Max Temp: 18.16
# Date:06-01-26 | Min Temp: 16.6 | Max Temp: 16.6
# Date:06-01-26 | Min Temp: 19.81 | Max Temp: 19.81
# Date:06-01-26 | Min Temp: 25.35 | Max Temp: 25.35
# Date:06-01-26 | Min Temp: 27.64 | Max Temp: 27.64
# Date:06-01-26 | Min Temp: 25.02 | Max Temp: 25.02
# Date:06-01-26 | Min Temp: 21.39 | Max Temp: 21.39
# Date:06-01-26 | Min Temp: 19.54 | Max Temp: 19.54
# Date:06-01-26 | Min Temp: 17.78 | Max Temp: 17.78
# Date:07-01-26 | Min Temp: 16.09 | Max Temp: 16.09
# Date:07-01-26 | Min Temp: 18.48 | Max Temp: 18.48
# Date:07-01-26 | Min Temp: 24.59 | Max Temp: 24.59
# Date:07-01-26 | Min Temp: 26.47 | Max Temp: 26.47
# Date:07-01-26 | Min Temp: 23.81 | Max Temp: 23.81
# Date:07-01-26 | Min Temp: 20.38 | Max Temp: 20.38
