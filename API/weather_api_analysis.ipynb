# %% [markdown]
# # Weather API Data Analysis – 10 Day Forecast

# %% [markdown]
# ## Objective
# To analyze 10-day weather forecast data for a selected city using a public Weather API, extract daily minimum and maximum temperatures, and identify the highest and lowest temperatures across the forecast period to understand short-term temperature patterns.

# %% [markdown]
# ## 1. Import Required Libraries

# %%
import requests
import json
from datetime import datetime

import os
from dotenv import load_dotenv

load_dotenv()
API_KEY = os.getenv("OPENWEATHER_API_KEY")

# %% [markdown]
# ## Data Source
# Weather data of Hyderabad city, India is fetched using the OpenWeather API, which returns forecast data in JSON format.

# %% [markdown]
# ## 2. API URL & Request

# %%
url=f'https://api.openweathermap.org/data/2.5/forecast?q=Hyderabad,IN&units=metric&appid={API_KEY}'
resp=requests.get(url)

# %% [markdown]
# ## 3. Response Validation

# %%
print(url)
# Out:
# https://api.openweathermap.org/data/2.5/forecast?q=Hyderabad,IN&units=metric&appid=54135abe53160ca54ae7094dedd58391

# %%
print(API_KEY)
# Out:
# 54135abe53160ca54ae7094dedd58391

# %%
print(resp.status_code)
# Out:
# 401

# %%
if resp.status_code==200:
    print("Response object loaded successfully")
    data=resp.content
else:
    print("Response object failed to load")
# Out:
# Response object loaded successfully

# %%
type(data)
# Out:
# bytes

# %% [markdown]
# ---
# ## 4. JSON Parsing (Bytes → Python Dictionary)

# %%
data=json.loads(data)

# %%
type(data)

# %%
data
# Out:
# {'cod': '200',
#  'message': 0,
#  'cnt': 40,
#  'list': [{'dt': 1767430800,
#    'main': {'temp': 25.23,
#     'feels_like': 25.3,
#     'temp_min': 25.23,
#     'temp_max': 28.24,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 949,
#     'humidity': 57,
#     'temp_kf': -3.01},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 10},
#    'wind': {'speed': 3.25, 'deg': 102, 'gust': 2.14},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-01-03 09:00:00'},
#   {'dt': 1767441600,
#    'main': {'temp': 25.5,
#     'feels_like': 25.44,
#     'temp_min': 25.5,
#     'temp_max': 26.04,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 949,
#     'humidity': 51,
#     'temp_kf': -0.54},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 15},
#    'wind': {'speed': 4.48, 'deg': 107, 'gust': 5.73},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-01-03 12:00:00'},
#   {'dt': 1767452400,
#    'main': {'temp': 24.63,
#     'feels_like': 24.45,
#     'temp_min': 24.33,
#     'temp_max': 24.63,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 952,
#     'humidity': 50,
#     'temp_kf': 0.3},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 58},
#    'wind': {'speed': 4.53, 'deg': 115, 'gust': 7.44},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-01-03 15:00:00'},
#   {'dt': 1767463200,
#    'main': {'temp': 21.56,
#     'feels_like': 21.26,
#     'temp_min': 21.56,
#     'temp_max': 21.56,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 952,
#     'humidity': 57,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 62},
#    'wind': {'speed': 4.06, 'deg': 116, 'gust': 8.86},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-01-03 18:00:00'},
#   {'dt': 1767474000,
#    'main': {'temp': 19.76,
#     'feels_like': 19.57,
#     'temp_min': 19.76,
#     'temp_max': 19.76,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 951,
#     'humidity': 68,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 10},
#    'wind': {'speed': 2.21, 'deg': 149, 'gust': 4.01},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-01-03 21:00:00'},
#   {'dt': 1767484800,
#    'main': {'temp': 17.87,
#     'feels_like': 17.91,
#     'temp_min': 17.87,
#     'temp_max': 17.87,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 951,
#     'humidity': 84,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 8},
#    'wind': {'speed': 2.78, 'deg': 132, 'gust': 4.44},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-01-04 00:00:00'},
#   {'dt': 1767495600,
#    'main': {'temp': 20.31,
#     'feels_like': 20.28,
#     'temp_min': 20.31,
#     'temp_max': 20.31,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 954,
#     'humidity': 72,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 4},
#    'wind': {'speed': 4.03, 'deg': 115, 'gust': 5.91},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-01-04 03:00:00'},
#   {'dt': 1767506400,
#    'main': {'temp': 26.05,
#     'feels_like': 26.05,
#     'temp_min': 26.05,
#     'temp_max': 26.05,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 953,
#     'humidity': 45,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 4},
#    'wind': {'speed': 3.92, 'deg': 109, 'gust': 3.77},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-01-04 06:00:00'},
#   {'dt': 1767517200,
#    'main': {'temp': 27.88,
#     'feels_like': 27.37,
#     'temp_min': 27.88,
#     'temp_max': 27.88,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 950,
#     'humidity': 37,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 9},
#    'wind': {'speed': 3.63, 'deg': 77, 'gust': 2.99},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-01-04 09:00:00'},
#   {'dt': 1767528000,
#    'main': {'temp': 25.95,
#     'feels_like': 25.95,
#     'temp_min': 25.95,
#     'temp_max': 25.95,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 950,
#     'humidity': 41,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 15},
#    'wind': {'speed': 3.76, 'deg': 100, 'gust': 4.91},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-01-04 12:00:00'},
#   {'dt': 1767538800,
#    'main': {'temp': 24.16,
#     'feels_like': 23.86,
#     'temp_min': 24.16,
#     'temp_max': 24.16,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 953,
#     'humidity': 47,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 85},
#    'wind': {'speed': 3.87, 'deg': 116, 'gust': 7.35},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-01-04 15:00:00'},
#   {'dt': 1767549600,
#    'main': {'temp': 23.11,
#     'feels_like': 22.81,
#     'temp_min': 23.11,
#     'temp_max': 23.11,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 952,
#     'humidity': 51,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 95},
#    'wind': {'speed': 3.31, 'deg': 105, 'gust': 6.64},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-01-04 18:00:00'},
#   {'dt': 1767560400,
#    'main': {'temp': 19.7,
#     'feels_like': 19.34,
#     'temp_min': 19.7,
#     'temp_max': 19.7,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 951,
#     'humidity': 62,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 2},
#    'wind': {'speed': 2.58, 'deg': 91, 'gust': 3.57},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-01-04 21:00:00'},
#   {'dt': 1767571200,
#    'main': {'temp': 18.07,
#     'feels_like': 17.73,
#     'temp_min': 18.07,
#     'temp_max': 18.07,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 952,
#     'humidity': 69,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 1},
#    'wind': {'speed': 2.91, 'deg': 81, 'gust': 4.22},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-01-05 00:00:00'},
#   {'dt': 1767582000,
#    'main': {'temp': 20.33,
#     'feels_like': 20.14,
#     'temp_min': 20.33,
#     'temp_max': 20.33,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 955,
#     'humidity': 66,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 2.95, 'deg': 112, 'gust': 4.56},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-01-05 03:00:00'},
#   {'dt': 1767592800,
#    'main': {'temp': 25.99,
#     'feels_like': 25.99,
#     'temp_min': 25.99,
#     'temp_max': 25.99,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 954,
#     'humidity': 41,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 1},
#    'wind': {'speed': 3.9, 'deg': 72, 'gust': 4.43},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-01-05 06:00:00'},
#   {'dt': 1767603600,
#    'main': {'temp': 28.15,
#     'feels_like': 27.21,
#     'temp_min': 28.15,
#     'temp_max': 28.15,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 950,
#     'humidity': 30,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 3},
#    'wind': {'speed': 3.85, 'deg': 50, 'gust': 4.64},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-01-05 09:00:00'},
#   {'dt': 1767614400,
#    'main': {'temp': 25.75,
#     'feels_like': 25.19,
#     'temp_min': 25.75,
#     'temp_max': 25.75,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 950,
#     'humidity': 31,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 2},
#    'wind': {'speed': 3.92, 'deg': 54, 'gust': 5.36},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-01-05 12:00:00'},
#   {'dt': 1767625200,
#    'main': {'temp': 21.31,
#     'feels_like': 20.49,
#     'temp_min': 21.31,
#     'temp_max': 21.31,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 953,
#     'humidity': 38,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 2},
#    'wind': {'speed': 3.25, 'deg': 55, 'gust': 5.15},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-01-05 15:00:00'},
#   {'dt': 1767636000,
#    'main': {'temp': 19.74,
#     'feels_like': 18.87,
#     'temp_min': 19.74,
#     'temp_max': 19.74,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 952,
#     'humidity': 42,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 1},
#    'wind': {'speed': 2, 'deg': 57, 'gust': 2.83},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-01-05 18:00:00'},
#   {'dt': 1767646800,
#    'main': {'temp': 18.37,
#     'feels_like': 17.39,
#     'temp_min': 18.37,
#     'temp_max': 18.37,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 951,
#     'humidity': 43,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 1},
#    'wind': {'speed': 2.14, 'deg': 62, 'gust': 2.97},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-01-05 21:00:00'},
#   {'dt': 1767657600,
#    'main': {'temp': 16.36,
#     'feels_like': 15.38,
#     'temp_min': 16.36,
#     'temp_max': 16.36,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 952,
#     'humidity': 51,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'clouds': {'all': 14},
#    'wind': {'speed': 2.57, 'deg': 84, 'gust': 3.33},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-01-06 00:00:00'},
#   {'dt': 1767668400,
#    'main': {'temp': 19.62,
#     'feels_like': 18.68,
#     'temp_min': 19.62,
#     'temp_max': 19.62,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 954,
#     'humidity': 40,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 15},
#    'wind': {'speed': 2.72, 'deg': 78, 'gust': 4.21},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-01-06 03:00:00'},
#   {'dt': 1767679200,
#    'main': {'temp': 25.61,
#     'feels_like': 24.93,
#     'temp_min': 25.61,
#     'temp_max': 25.61,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 953,
#     'humidity': 27,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 31},
#    'wind': {'speed': 3.88, 'deg': 78, 'gust': 4.74},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-01-06 06:00:00'},
#   {'dt': 1767690000,
#    'main': {'temp': 27.55,
#     'feels_like': 26.62,
#     'temp_min': 27.55,
#     'temp_max': 27.55,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 950,
#     'humidity': 26,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 19},
#    'wind': {'speed': 4.13, 'deg': 84, 'gust': 4.47},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-01-06 09:00:00'},
#   {'dt': 1767700800,
#    'main': {'temp': 24.89,
#     'feels_like': 24.45,
#     'temp_min': 24.89,
#     'temp_max': 24.89,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 951,
#     'humidity': 39,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 50},
#    'wind': {'speed': 3.16, 'deg': 91, 'gust': 4.32},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-01-06 12:00:00'},
#   {'dt': 1767711600,
#    'main': {'temp': 21.2,
#     'feels_like': 20.71,
#     'temp_min': 21.2,
#     'temp_max': 21.2,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 953,
#     'humidity': 51,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 92},
#    'wind': {'speed': 3.18, 'deg': 112, 'gust': 5.36},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-01-06 15:00:00'},
#   {'dt': 1767722400,
#    'main': {'temp': 19.44,
#     'feels_like': 19.01,
#     'temp_min': 19.44,
#     'temp_max': 19.44,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 953,
#     'humidity': 60,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 66},
#    'wind': {'speed': 1.7, 'deg': 120, 'gust': 2.28},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-01-06 18:00:00'},
#   {'dt': 1767733200,
#    'main': {'temp': 17.83,
#     'feels_like': 17.42,
#     'temp_min': 17.83,
#     'temp_max': 17.83,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 951,
#     'humidity': 67,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.68, 'deg': 90, 'gust': 3.48},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-01-06 21:00:00'},
#   {'dt': 1767744000,
#    'main': {'temp': 16.35,
#     'feels_like': 16.44,
#     'temp_min': 16.35,
#     'temp_max': 16.35,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 952,
#     'humidity': 92,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.09, 'deg': 112, 'gust': 5.2},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-01-07 00:00:00'},
#   {'dt': 1767754800,
#    'main': {'temp': 18.78,
#     'feels_like': 18.88,
#     'temp_min': 18.78,
#     'temp_max': 18.78,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 954,
#     'humidity': 83,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 84},
#    'wind': {'speed': 3.96, 'deg': 128, 'gust': 5.68},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-01-07 03:00:00'},
#   {'dt': 1767765600,
#    'main': {'temp': 24.76,
#     'feels_like': 24.49,
#     'temp_min': 24.76,
#     'temp_max': 24.76,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 954,
#     'humidity': 46,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 65},
#    'wind': {'speed': 3.72, 'deg': 111, 'gust': 4.26},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-01-07 06:00:00'},
#   {'dt': 1767776400,
#    'main': {'temp': 27.1,
#     'feels_like': 26.56,
#     'temp_min': 27.1,
#     'temp_max': 27.1,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 950,
#     'humidity': 32,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 36},
#    'wind': {'speed': 4.09, 'deg': 102, 'gust': 4.19},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-01-07 09:00:00'},
#   {'dt': 1767787200,
#    'main': {'temp': 24.67,
#     'feels_like': 24.21,
#     'temp_min': 24.67,
#     'temp_max': 24.67,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 951,
#     'humidity': 39,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 20},
#    'wind': {'speed': 4.09, 'deg': 110, 'gust': 5.28},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-01-07 12:00:00'},
#   {'dt': 1767798000,
#    'main': {'temp': 20.78,
#     'feels_like': 20.27,
#     'temp_min': 20.78,
#     'temp_max': 20.78,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 953,
#     'humidity': 52,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 33},
#    'wind': {'speed': 3.23, 'deg': 134, 'gust': 4.73},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-01-07 15:00:00'},
#   {'dt': 1767808800,
#    'main': {'temp': 19.32,
#     'feels_like': 18.85,
#     'temp_min': 19.32,
#     'temp_max': 19.32,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 953,
#     'humidity': 59,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 60},
#    'wind': {'speed': 2.18, 'deg': 144, 'gust': 2.73},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-01-07 18:00:00'},
#   {'dt': 1767819600,
#    'main': {'temp': 17.6,
#     'feels_like': 17.3,
#     'temp_min': 17.6,
#     'temp_max': 17.6,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 952,
#     'humidity': 72,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.92, 'deg': 150, 'gust': 4.4},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-01-07 21:00:00'},
#   {'dt': 1767830400,
#    'main': {'temp': 16.14,
#     'feels_like': 16.06,
#     'temp_min': 16.14,
#     'temp_max': 16.14,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 953,
#     'humidity': 86,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 96},
#    'wind': {'speed': 2.5, 'deg': 127, 'gust': 3.15},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2026-01-08 00:00:00'},
#   {'dt': 1767841200,
#    'main': {'temp': 18.85,
#     'feels_like': 18.62,
#     'temp_min': 18.85,
#     'temp_max': 18.85,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 955,
#     'humidity': 70,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 37},
#    'wind': {'speed': 3.25, 'deg': 127, 'gust': 4.7},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-01-08 03:00:00'},
#   {'dt': 1767852000,
#    'main': {'temp': 24.88,
#     'feels_like': 24.44,
#     'temp_min': 24.88,
#     'temp_max': 24.88,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 955,
#     'humidity': 39,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 22},
#    'wind': {'speed': 4.56, 'deg': 111, 'gust': 5.36},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2026-01-08 06:00:00'}],
#  'city': {'id': 1269843,
#   'name': 'Hyderabad',
#   'coord': {'lat': 17.3753, 'lon': 78.4744},
#   'country': 'IN',
#   'population': 3597816,
#   'timezone': 19800,
#   'sunrise': 1767403004,
#   'sunset': 1767443024}}

# %% [markdown]
# ## 5. Data Structure Exploration

# %%
data.keys()
# Out:
# dict_keys(['cod', 'message', 'cnt', 'list', 'city'])

# %%
print(type(data['list']))
# Out:
# <class 'list'>

# %%
data['list']
# Out:
# [{'dt': 1767430800,
#   'main': {'temp': 25.23,
#    'feels_like': 25.3,
#    'temp_min': 25.23,
#    'temp_max': 28.24,
#    'pressure': 1012,
#    'sea_level': 1012,
#    'grnd_level': 949,
#    'humidity': 57,
#    'temp_kf': -3.01},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'clouds': {'all': 10},
#   'wind': {'speed': 3.25, 'deg': 102, 'gust': 2.14},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-01-03 09:00:00'},
#  {'dt': 1767441600,
#   'main': {'temp': 25.5,
#    'feels_like': 25.44,
#    'temp_min': 25.5,
#    'temp_max': 26.04,
#    'pressure': 1012,
#    'sea_level': 1012,
#    'grnd_level': 949,
#    'humidity': 51,
#    'temp_kf': -0.54},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'clouds': {'all': 15},
#   'wind': {'speed': 4.48, 'deg': 107, 'gust': 5.73},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-01-03 12:00:00'},
#  {'dt': 1767452400,
#   'main': {'temp': 24.63,
#    'feels_like': 24.45,
#    'temp_min': 24.33,
#    'temp_max': 24.63,
#    'pressure': 1015,
#    'sea_level': 1015,
#    'grnd_level': 952,
#    'humidity': 50,
#    'temp_kf': 0.3},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 58},
#   'wind': {'speed': 4.53, 'deg': 115, 'gust': 7.44},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-01-03 15:00:00'},
#  {'dt': 1767463200,
#   'main': {'temp': 21.56,
#    'feels_like': 21.26,
#    'temp_min': 21.56,
#    'temp_max': 21.56,
#    'pressure': 1016,
#    'sea_level': 1016,
#    'grnd_level': 952,
#    'humidity': 57,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 62},
#   'wind': {'speed': 4.06, 'deg': 116, 'gust': 8.86},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-01-03 18:00:00'},
#  {'dt': 1767474000,
#   'main': {'temp': 19.76,
#    'feels_like': 19.57,
#    'temp_min': 19.76,
#    'temp_max': 19.76,
#    'pressure': 1014,
#    'sea_level': 1014,
#    'grnd_level': 951,
#    'humidity': 68,
#    'temp_kf': 0},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'clouds': {'all': 10},
#   'wind': {'speed': 2.21, 'deg': 149, 'gust': 4.01},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-01-03 21:00:00'},
#  {'dt': 1767484800,
#   'main': {'temp': 17.87,
#    'feels_like': 17.91,
#    'temp_min': 17.87,
#    'temp_max': 17.87,
#    'pressure': 1015,
#    'sea_level': 1015,
#    'grnd_level': 951,
#    'humidity': 84,
#    'temp_kf': 0},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'clouds': {'all': 8},
#   'wind': {'speed': 2.78, 'deg': 132, 'gust': 4.44},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-01-04 00:00:00'},
#  {'dt': 1767495600,
#   'main': {'temp': 20.31,
#    'feels_like': 20.28,
#    'temp_min': 20.31,
#    'temp_max': 20.31,
#    'pressure': 1018,
#    'sea_level': 1018,
#    'grnd_level': 954,
#    'humidity': 72,
#    'temp_kf': 0},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'clouds': {'all': 4},
#   'wind': {'speed': 4.03, 'deg': 115, 'gust': 5.91},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-01-04 03:00:00'},
#  {'dt': 1767506400,
#   'main': {'temp': 26.05,
#    'feels_like': 26.05,
#    'temp_min': 26.05,
#    'temp_max': 26.05,
#    'pressure': 1017,
#    'sea_level': 1017,
#    'grnd_level': 953,
#    'humidity': 45,
#    'temp_kf': 0},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'clouds': {'all': 4},
#   'wind': {'speed': 3.92, 'deg': 109, 'gust': 3.77},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-01-04 06:00:00'},
#  {'dt': 1767517200,
#   'main': {'temp': 27.88,
#    'feels_like': 27.37,
#    'temp_min': 27.88,
#    'temp_max': 27.88,
#    'pressure': 1013,
#    'sea_level': 1013,
#    'grnd_level': 950,
#    'humidity': 37,
#    'temp_kf': 0},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'clouds': {'all': 9},
#   'wind': {'speed': 3.63, 'deg': 77, 'gust': 2.99},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-01-04 09:00:00'},
#  {'dt': 1767528000,
#   'main': {'temp': 25.95,
#    'feels_like': 25.95,
#    'temp_min': 25.95,
#    'temp_max': 25.95,
#    'pressure': 1014,
#    'sea_level': 1014,
#    'grnd_level': 950,
#    'humidity': 41,
#    'temp_kf': 0},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'clouds': {'all': 15},
#   'wind': {'speed': 3.76, 'deg': 100, 'gust': 4.91},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-01-04 12:00:00'},
#  {'dt': 1767538800,
#   'main': {'temp': 24.16,
#    'feels_like': 23.86,
#    'temp_min': 24.16,
#    'temp_max': 24.16,
#    'pressure': 1017,
#    'sea_level': 1017,
#    'grnd_level': 953,
#    'humidity': 47,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 85},
#   'wind': {'speed': 3.87, 'deg': 116, 'gust': 7.35},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-01-04 15:00:00'},
#  {'dt': 1767549600,
#   'main': {'temp': 23.11,
#    'feels_like': 22.81,
#    'temp_min': 23.11,
#    'temp_max': 23.11,
#    'pressure': 1016,
#    'sea_level': 1016,
#    'grnd_level': 952,
#    'humidity': 51,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 95},
#   'wind': {'speed': 3.31, 'deg': 105, 'gust': 6.64},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-01-04 18:00:00'},
#  {'dt': 1767560400,
#   'main': {'temp': 19.7,
#    'feels_like': 19.34,
#    'temp_min': 19.7,
#    'temp_max': 19.7,
#    'pressure': 1015,
#    'sea_level': 1015,
#    'grnd_level': 951,
#    'humidity': 62,
#    'temp_kf': 0},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'clouds': {'all': 2},
#   'wind': {'speed': 2.58, 'deg': 91, 'gust': 3.57},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-01-04 21:00:00'},
#  {'dt': 1767571200,
#   'main': {'temp': 18.07,
#    'feels_like': 17.73,
#    'temp_min': 18.07,
#    'temp_max': 18.07,
#    'pressure': 1016,
#    'sea_level': 1016,
#    'grnd_level': 952,
#    'humidity': 69,
#    'temp_kf': 0},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'clouds': {'all': 1},
#   'wind': {'speed': 2.91, 'deg': 81, 'gust': 4.22},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-01-05 00:00:00'},
#  {'dt': 1767582000,
#   'main': {'temp': 20.33,
#    'feels_like': 20.14,
#    'temp_min': 20.33,
#    'temp_max': 20.33,
#    'pressure': 1019,
#    'sea_level': 1019,
#    'grnd_level': 955,
#    'humidity': 66,
#    'temp_kf': 0},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'clouds': {'all': 0},
#   'wind': {'speed': 2.95, 'deg': 112, 'gust': 4.56},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-01-05 03:00:00'},
#  {'dt': 1767592800,
#   'main': {'temp': 25.99,
#    'feels_like': 25.99,
#    'temp_min': 25.99,
#    'temp_max': 25.99,
#    'pressure': 1017,
#    'sea_level': 1017,
#    'grnd_level': 954,
#    'humidity': 41,
#    'temp_kf': 0},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'clouds': {'all': 1},
#   'wind': {'speed': 3.9, 'deg': 72, 'gust': 4.43},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-01-05 06:00:00'},
#  {'dt': 1767603600,
#   'main': {'temp': 28.15,
#    'feels_like': 27.21,
#    'temp_min': 28.15,
#    'temp_max': 28.15,
#    'pressure': 1013,
#    'sea_level': 1013,
#    'grnd_level': 950,
#    'humidity': 30,
#    'temp_kf': 0},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'clouds': {'all': 3},
#   'wind': {'speed': 3.85, 'deg': 50, 'gust': 4.64},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-01-05 09:00:00'},
#  {'dt': 1767614400,
#   'main': {'temp': 25.75,
#    'feels_like': 25.19,
#    'temp_min': 25.75,
#    'temp_max': 25.75,
#    'pressure': 1014,
#    'sea_level': 1014,
#    'grnd_level': 950,
#    'humidity': 31,
#    'temp_kf': 0},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'clouds': {'all': 2},
#   'wind': {'speed': 3.92, 'deg': 54, 'gust': 5.36},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-01-05 12:00:00'},
#  {'dt': 1767625200,
#   'main': {'temp': 21.31,
#    'feels_like': 20.49,
#    'temp_min': 21.31,
#    'temp_max': 21.31,
#    'pressure': 1017,
#    'sea_level': 1017,
#    'grnd_level': 953,
#    'humidity': 38,
#    'temp_kf': 0},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'clouds': {'all': 2},
#   'wind': {'speed': 3.25, 'deg': 55, 'gust': 5.15},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-01-05 15:00:00'},
#  {'dt': 1767636000,
#   'main': {'temp': 19.74,
#    'feels_like': 18.87,
#    'temp_min': 19.74,
#    'temp_max': 19.74,
#    'pressure': 1016,
#    'sea_level': 1016,
#    'grnd_level': 952,
#    'humidity': 42,
#    'temp_kf': 0},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'clouds': {'all': 1},
#   'wind': {'speed': 2, 'deg': 57, 'gust': 2.83},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-01-05 18:00:00'},
#  {'dt': 1767646800,
#   'main': {'temp': 18.37,
#    'feels_like': 17.39,
#    'temp_min': 18.37,
#    'temp_max': 18.37,
#    'pressure': 1015,
#    'sea_level': 1015,
#    'grnd_level': 951,
#    'humidity': 43,
#    'temp_kf': 0},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'clouds': {'all': 1},
#   'wind': {'speed': 2.14, 'deg': 62, 'gust': 2.97},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-01-05 21:00:00'},
#  {'dt': 1767657600,
#   'main': {'temp': 16.36,
#    'feels_like': 15.38,
#    'temp_min': 16.36,
#    'temp_max': 16.36,
#    'pressure': 1016,
#    'sea_level': 1016,
#    'grnd_level': 952,
#    'humidity': 51,
#    'temp_kf': 0},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'clouds': {'all': 14},
#   'wind': {'speed': 2.57, 'deg': 84, 'gust': 3.33},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-01-06 00:00:00'},
#  {'dt': 1767668400,
#   'main': {'temp': 19.62,
#    'feels_like': 18.68,
#    'temp_min': 19.62,
#    'temp_max': 19.62,
#    'pressure': 1018,
#    'sea_level': 1018,
#    'grnd_level': 954,
#    'humidity': 40,
#    'temp_kf': 0},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'clouds': {'all': 15},
#   'wind': {'speed': 2.72, 'deg': 78, 'gust': 4.21},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-01-06 03:00:00'},
#  {'dt': 1767679200,
#   'main': {'temp': 25.61,
#    'feels_like': 24.93,
#    'temp_min': 25.61,
#    'temp_max': 25.61,
#    'pressure': 1017,
#    'sea_level': 1017,
#    'grnd_level': 953,
#    'humidity': 27,
#    'temp_kf': 0},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'clouds': {'all': 31},
#   'wind': {'speed': 3.88, 'deg': 78, 'gust': 4.74},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-01-06 06:00:00'},
#  {'dt': 1767690000,
#   'main': {'temp': 27.55,
#    'feels_like': 26.62,
#    'temp_min': 27.55,
#    'temp_max': 27.55,
#    'pressure': 1013,
#    'sea_level': 1013,
#    'grnd_level': 950,
#    'humidity': 26,
#    'temp_kf': 0},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'clouds': {'all': 19},
#   'wind': {'speed': 4.13, 'deg': 84, 'gust': 4.47},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-01-06 09:00:00'},
#  {'dt': 1767700800,
#   'main': {'temp': 24.89,
#    'feels_like': 24.45,
#    'temp_min': 24.89,
#    'temp_max': 24.89,
#    'pressure': 1014,
#    'sea_level': 1014,
#    'grnd_level': 951,
#    'humidity': 39,
#    'temp_kf': 0},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'clouds': {'all': 50},
#   'wind': {'speed': 3.16, 'deg': 91, 'gust': 4.32},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-01-06 12:00:00'},
#  {'dt': 1767711600,
#   'main': {'temp': 21.2,
#    'feels_like': 20.71,
#    'temp_min': 21.2,
#    'temp_max': 21.2,
#    'pressure': 1017,
#    'sea_level': 1017,
#    'grnd_level': 953,
#    'humidity': 51,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 92},
#   'wind': {'speed': 3.18, 'deg': 112, 'gust': 5.36},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-01-06 15:00:00'},
#  {'dt': 1767722400,
#   'main': {'temp': 19.44,
#    'feels_like': 19.01,
#    'temp_min': 19.44,
#    'temp_max': 19.44,
#    'pressure': 1017,
#    'sea_level': 1017,
#    'grnd_level': 953,
#    'humidity': 60,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 66},
#   'wind': {'speed': 1.7, 'deg': 120, 'gust': 2.28},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-01-06 18:00:00'},
#  {'dt': 1767733200,
#   'main': {'temp': 17.83,
#    'feels_like': 17.42,
#    'temp_min': 17.83,
#    'temp_max': 17.83,
#    'pressure': 1016,
#    'sea_level': 1016,
#    'grnd_level': 951,
#    'humidity': 67,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 2.68, 'deg': 90, 'gust': 3.48},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-01-06 21:00:00'},
#  {'dt': 1767744000,
#   'main': {'temp': 16.35,
#    'feels_like': 16.44,
#    'temp_min': 16.35,
#    'temp_max': 16.35,
#    'pressure': 1017,
#    'sea_level': 1017,
#    'grnd_level': 952,
#    'humidity': 92,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 3.09, 'deg': 112, 'gust': 5.2},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-01-07 00:00:00'},
#  {'dt': 1767754800,
#   'main': {'temp': 18.78,
#    'feels_like': 18.88,
#    'temp_min': 18.78,
#    'temp_max': 18.78,
#    'pressure': 1019,
#    'sea_level': 1019,
#    'grnd_level': 954,
#    'humidity': 83,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 84},
#   'wind': {'speed': 3.96, 'deg': 128, 'gust': 5.68},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-01-07 03:00:00'},
#  {'dt': 1767765600,
#   'main': {'temp': 24.76,
#    'feels_like': 24.49,
#    'temp_min': 24.76,
#    'temp_max': 24.76,
#    'pressure': 1018,
#    'sea_level': 1018,
#    'grnd_level': 954,
#    'humidity': 46,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'clouds': {'all': 65},
#   'wind': {'speed': 3.72, 'deg': 111, 'gust': 4.26},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-01-07 06:00:00'},
#  {'dt': 1767776400,
#   'main': {'temp': 27.1,
#    'feels_like': 26.56,
#    'temp_min': 27.1,
#    'temp_max': 27.1,
#    'pressure': 1014,
#    'sea_level': 1014,
#    'grnd_level': 950,
#    'humidity': 32,
#    'temp_kf': 0},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'clouds': {'all': 36},
#   'wind': {'speed': 4.09, 'deg': 102, 'gust': 4.19},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-01-07 09:00:00'},
#  {'dt': 1767787200,
#   'main': {'temp': 24.67,
#    'feels_like': 24.21,
#    'temp_min': 24.67,
#    'temp_max': 24.67,
#    'pressure': 1014,
#    'sea_level': 1014,
#    'grnd_level': 951,
#    'humidity': 39,
#    'temp_kf': 0},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'clouds': {'all': 20},
#   'wind': {'speed': 4.09, 'deg': 110, 'gust': 5.28},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-01-07 12:00:00'},
#  {'dt': 1767798000,
#   'main': {'temp': 20.78,
#    'feels_like': 20.27,
#    'temp_min': 20.78,
#    'temp_max': 20.78,
#    'pressure': 1017,
#    'sea_level': 1017,
#    'grnd_level': 953,
#    'humidity': 52,
#    'temp_kf': 0},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'clouds': {'all': 33},
#   'wind': {'speed': 3.23, 'deg': 134, 'gust': 4.73},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-01-07 15:00:00'},
#  {'dt': 1767808800,
#   'main': {'temp': 19.32,
#    'feels_like': 18.85,
#    'temp_min': 19.32,
#    'temp_max': 19.32,
#    'pressure': 1017,
#    'sea_level': 1017,
#    'grnd_level': 953,
#    'humidity': 59,
#    'temp_kf': 0},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 60},
#   'wind': {'speed': 2.18, 'deg': 144, 'gust': 2.73},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-01-07 18:00:00'},
#  {'dt': 1767819600,
#   'main': {'temp': 17.6,
#    'feels_like': 17.3,
#    'temp_min': 17.6,
#    'temp_max': 17.6,
#    'pressure': 1017,
#    'sea_level': 1017,
#    'grnd_level': 952,
#    'humidity': 72,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 100},
#   'wind': {'speed': 2.92, 'deg': 150, 'gust': 4.4},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-01-07 21:00:00'},
#  {'dt': 1767830400,
#   'main': {'temp': 16.14,
#    'feels_like': 16.06,
#    'temp_min': 16.14,
#    'temp_max': 16.14,
#    'pressure': 1017,
#    'sea_level': 1017,
#    'grnd_level': 953,
#    'humidity': 86,
#    'temp_kf': 0},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'clouds': {'all': 96},
#   'wind': {'speed': 2.5, 'deg': 127, 'gust': 3.15},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'n'},
#   'dt_txt': '2026-01-08 00:00:00'},
#  {'dt': 1767841200,
#   'main': {'temp': 18.85,
#    'feels_like': 18.62,
#    'temp_min': 18.85,
#    'temp_max': 18.85,
#    'pressure': 1019,
#    'sea_level': 1019,
#    'grnd_level': 955,
#    'humidity': 70,
#    'temp_kf': 0},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'clouds': {'all': 37},
#   'wind': {'speed': 3.25, 'deg': 127, 'gust': 4.7},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-01-08 03:00:00'},
#  {'dt': 1767852000,
#   'main': {'temp': 24.88,
#    'feels_like': 24.44,
#    'temp_min': 24.88,
#    'temp_max': 24.88,
#    'pressure': 1019,
#    'sea_level': 1019,
#    'grnd_level': 955,
#    'humidity': 39,
#    'temp_kf': 0},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'clouds': {'all': 22},
#   'wind': {'speed': 4.56, 'deg': 111, 'gust': 5.36},
#   'visibility': 10000,
#   'pop': 0,
#   'sys': {'pod': 'd'},
#   'dt_txt': '2026-01-08 06:00:00'}]

# %%
data.keys()
# Out:
# dict_keys(['cod', 'message', 'cnt', 'list', 'city'])

# %%
data['list'][0] # we have our analysis required 'dt' in list, and min and max temperatures in temp list.
# Out:
# {'dt': 1767430800,
#  'main': {'temp': 25.23,
#   'feels_like': 25.3,
#   'temp_min': 25.23,
#   'temp_max': 28.24,
#   'pressure': 1012,
#   'sea_level': 1012,
#   'grnd_level': 949,
#   'humidity': 57,
#   'temp_kf': -3.01},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01d'}],
#  'clouds': {'all': 10},
#  'wind': {'speed': 3.25, 'deg': 102, 'gust': 2.14},
#  'visibility': 10000,
#  'pop': 0,
#  'sys': {'pod': 'd'},
#  'dt_txt': '2026-01-03 09:00:00'}

# %%
data['list'][0].keys()
# Out:
# dict_keys(['dt', 'main', 'weather', 'clouds', 'wind', 'visibility', 'pop', 'sys', 'dt_txt'])

# %%
print(type(data['list'][0]['main']))
# Out:
# <class 'dict'>

# %%
print(data['list'][0]['main'].keys())
# Out:
# dict_keys(['temp', 'feels_like', 'temp_min', 'temp_max', 'pressure', 'sea_level', 'grnd_level', 'humidity', 'temp_kf'])

# %%
weather_list=data['list']
weather_list[0]['main']
# Out:
# {'temp': 25.23,
#  'feels_like': 25.3,
#  'temp_min': 25.23,
#  'temp_max': 28.24,
#  'pressure': 1012,
#  'sea_level': 1012,
#  'grnd_level': 949,
#  'humidity': 57,
#  'temp_kf': -3.01}

# %%
weather_list[0]['dt'] # use datetime
# Out:
# 1767430800

# %% [markdown]
# ## 6. Daily Temperature Extraction

# %%
from datetime import datetime, UTC
maxtemp=[]
mintemp=[] # to collect max and min temperatures from temp.

for each in weather_list:
    date_ts=each['dt'] #this gives unix timestamp
    date=datetime.fromtimestamp(date_ts, UTC).strftime('%d-%m-%y') #correct date conversion
    maxtemp=each['main']['temp_max']
    mintemp=each['main']['temp_min']

    print(f'Date:{date} | Min Temp: {mintemp} | Max Temp: {maxtemp}')
# Out:
# Date:03-01-26 | Min Temp: 25.23 | Max Temp: 28.24
# Date:03-01-26 | Min Temp: 25.5 | Max Temp: 26.04
# Date:03-01-26 | Min Temp: 24.33 | Max Temp: 24.63
# Date:03-01-26 | Min Temp: 21.56 | Max Temp: 21.56
# Date:03-01-26 | Min Temp: 19.76 | Max Temp: 19.76
# Date:04-01-26 | Min Temp: 17.87 | Max Temp: 17.87
# Date:04-01-26 | Min Temp: 20.31 | Max Temp: 20.31
# Date:04-01-26 | Min Temp: 26.05 | Max Temp: 26.05
# Date:04-01-26 | Min Temp: 27.88 | Max Temp: 27.88
# Date:04-01-26 | Min Temp: 25.95 | Max Temp: 25.95
# Date:04-01-26 | Min Temp: 24.16 | Max Temp: 24.16
# Date:04-01-26 | Min Temp: 23.11 | Max Temp: 23.11
# Date:04-01-26 | Min Temp: 19.7 | Max Temp: 19.7
# Date:05-01-26 | Min Temp: 18.07 | Max Temp: 18.07
# Date:05-01-26 | Min Temp: 20.33 | Max Temp: 20.33
# Date:05-01-26 | Min Temp: 25.99 | Max Temp: 25.99
# Date:05-01-26 | Min Temp: 28.15 | Max Temp: 28.15
# Date:05-01-26 | Min Temp: 25.75 | Max Temp: 25.75
# Date:05-01-26 | Min Temp: 21.31 | Max Temp: 21.31
# Date:05-01-26 | Min Temp: 19.74 | Max Temp: 19.74
# Date:05-01-26 | Min Temp: 18.37 | Max Temp: 18.37
# Date:06-01-26 | Min Temp: 16.36 | Max Temp: 16.36
# Date:06-01-26 | Min Temp: 19.62 | Max Temp: 19.62
# Date:06-01-26 | Min Temp: 25.61 | Max Temp: 25.61
# Date:06-01-26 | Min Temp: 27.55 | Max Temp: 27.55
# Date:06-01-26 | Min Temp: 24.89 | Max Temp: 24.89
# Date:06-01-26 | Min Temp: 21.2 | Max Temp: 21.2
# Date:06-01-26 | Min Temp: 19.44 | Max Temp: 19.44
# Date:06-01-26 | Min Temp: 17.83 | Max Temp: 17.83
# Date:07-01-26 | Min Temp: 16.35 | Max Temp: 16.35
# Date:07-01-26 | Min Temp: 18.78 | Max Temp: 18.78
# Date:07-01-26 | Min Temp: 24.76 | Max Temp: 24.76
# Date:07-01-26 | Min Temp: 27.1 | Max Temp: 27.1
# Date:07-01-26 | Min Temp: 24.67 | Max Temp: 24.67
# Date:07-01-26 | Min Temp: 20.78 | Max Temp: 20.78
# Date:07-01-26 | Min Temp: 19.32 | Max Temp: 19.32
# Date:07-01-26 | Min Temp: 17.6 | Max Temp: 17.6
# Date:08-01-26 | Min Temp: 16.14 | Max Temp: 16.14
# Date:08-01-26 | Min Temp: 18.85 | Max Temp: 18.85
# Date:08-01-26 | Min Temp: 24.88 | Max Temp: 24.88

# %% [markdown]
# ---
# ## 7: Daily Temperature Aggregation (CORE ANALYSIS)

# %% [markdown]
# ### 7.1 Create a structured list (row-wise data)

# %%
rows=[]
for each in weather_list:
    date=datetime.fromtimestamp(each['dt'],UTC).strftime('%d-%m-%y')
    min_temp=each['main']['temp_min']
    max_temp=each['main']['temp_max']

    rows.append([date,min_temp,max_temp])
rows #rows is a list, each item inside it is also a list. This structure is called List of lists
# Out:
# [['03-01-26', 25.23, 28.24],
#  ['03-01-26', 25.5, 26.04],
#  ['03-01-26', 24.33, 24.63],
#  ['03-01-26', 21.56, 21.56],
#  ['03-01-26', 19.76, 19.76],
#  ['04-01-26', 17.87, 17.87],
#  ['04-01-26', 20.31, 20.31],
#  ['04-01-26', 26.05, 26.05],
#  ['04-01-26', 27.88, 27.88],
#  ['04-01-26', 25.95, 25.95],
#  ['04-01-26', 24.16, 24.16],
#  ['04-01-26', 23.11, 23.11],
#  ['04-01-26', 19.7, 19.7],
#  ['05-01-26', 18.07, 18.07],
#  ['05-01-26', 20.33, 20.33],
#  ['05-01-26', 25.99, 25.99],
#  ['05-01-26', 28.15, 28.15],
#  ['05-01-26', 25.75, 25.75],
#  ['05-01-26', 21.31, 21.31],
#  ['05-01-26', 19.74, 19.74],
#  ['05-01-26', 18.37, 18.37],
#  ['06-01-26', 16.36, 16.36],
#  ['06-01-26', 19.62, 19.62],
#  ['06-01-26', 25.61, 25.61],
#  ['06-01-26', 27.55, 27.55],
#  ['06-01-26', 24.89, 24.89],
#  ['06-01-26', 21.2, 21.2],
#  ['06-01-26', 19.44, 19.44],
#  ['06-01-26', 17.83, 17.83],
#  ['07-01-26', 16.35, 16.35],
#  ['07-01-26', 18.78, 18.78],
#  ['07-01-26', 24.76, 24.76],
#  ['07-01-26', 27.1, 27.1],
#  ['07-01-26', 24.67, 24.67],
#  ['07-01-26', 20.78, 20.78],
#  ['07-01-26', 19.32, 19.32],
#  ['07-01-26', 17.6, 17.6],
#  ['08-01-26', 16.14, 16.14],
#  ['08-01-26', 18.85, 18.85],
#  ['08-01-26', 24.88, 24.88]]

# %% [markdown]
# ---
# ### 7.2: Convert list to DataFrame

# %%
import pandas as pd
df=pd.DataFrame(rows,columns=['Date','Min_Temp','Max_Temp']) # This line converts a list of extracted values into a structured pandas DataFrame with named columns.
df.head()
# Out:
#        Date  Min_Temp  Max_Temp
# 0  03-01-26     25.23     28.24
# 1  03-01-26     25.50     26.04
# 2  03-01-26     24.33     24.63
# 3  03-01-26     21.56     21.56
# 4  03-01-26     19.76     19.76

# %% [markdown]
# ---
# ### 7.3: Aggregate to DAILY level

# %% [markdown]
# #Group by Date → find min and max for each group

# %%
daily_weather = df.groupby('Date')[['Min_Temp', 'Max_Temp']].agg({
    'Min_Temp': 'min',
    'Max_Temp': 'max'
}).reset_index()
daily_weather.head()
# Out:
#        Date  Min_Temp  Max_Temp
# 0  03-01-26     19.76     28.24
# 1  04-01-26     17.87     27.88
# 2  05-01-26     18.07     28.15
# 3  06-01-26     16.36     27.55
# 4  07-01-26     16.35     27.10

# %% [markdown]
# ---
# ## Insights
#
# - The weather forecast data is available at 3-hour intervals and was aggregated to daily level for analysis.
# - Daily minimum and maximum temperatures vary noticeably across days, indicating clear intraday temperature fluctuations.
# - Peak temperatures are consistently higher than early morning or night-time temperatures.
# - Aggregating data to daily level makes the forecast easier to interpret and suitable for trend analysis.
